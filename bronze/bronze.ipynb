# %%
print("Hello")

# %%
# %sql
create volume databricksdan.bronze.bronze_volume

# %%
# %sql
select * from csv.`/Volumes/databricksdan/bronze/bronze_volume/sales/fact_sales.csv`

# %%
dbutils.fs.ls("/Volumes/databricksdan/bronze/bronze_volume")

# %%
dbutils.fs.mkdirs("/Volumes/databricksdan/bronze/bronze_volume/customers")
